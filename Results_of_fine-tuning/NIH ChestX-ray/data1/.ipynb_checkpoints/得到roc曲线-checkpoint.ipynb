# %%
import pandas as pd
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt
import os
import random
import numpy as np

# %%
caption_path = "./caption_1_bestauc_checkpoint"
Densenet121_path = "./Densenet121_1_bestloss_checkpoint"
google_path = "./google_1_bestloss_checkpoint"
resnet18_path = "./resnet18_1_bestloss_checkpoint"
resnet50_path = "./resnet50_1_bestloss_checkpoint"
resnet101_path = "./resnet101_1_bestloss_checkpoint"
simclr_path = "./simclr_1_bestauc_checkpoint"
vit_path = "./vit_1_bestloss_checkpoint"

# %%
one_name = "Atelectasis.txt"
two_name = "Cardiomegaly.txt"
three_name = "Consolidation.txt"
four_name = "Edema.txt"
five_name = "Effusion.txt"
six_name = "Emphysema.txt"
seven_name = "Fibrosis.txt"
eight_name = "Hernia.txt"
nine_name = "Infiltration.txt"
ten_name = "Mass.txt"
eleven_name = "Nodule.txt"
twelve_name = "Pleural_Thickening.txt"
thirteen_name = "Pneumonia.txt"
fourteen_name = "Pneumothorax.txt"

# %%
file_name_list = [one_name,two_name,three_name,four_name,five_name,six_name,seven_name,eight_name,nine_name,ten_name,eleven_name,twelve_name,thirteen_name,fourteen_name]

# %%
# caption
roc_auc_0_list = []
roc_auc_3_list = []
roc_auc_6_list = []
roc_auc_7_list = []
roc_auc_2_list = []

fname_list = ["Atelectasis", "Cardiomegaly", "Consolidation", "Edema", "Effusion", "Emphysema", "Fibrosis", "Hernia", "Infiltration", "Mass", "Nodule", "Pleural Thickening", "Pneumonia", "Pneumothorax"]
mg_m = []
cr_m = []
c2l_m = []
vw_m = []
in_m = []
ours_m = []

c=0
for compare_name in file_name_list:
    y_true = []
    y_scores = []
    filepath_1 = os.path.join(caption_path,compare_name)
    with open(filepath_1,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))
        
    fpr_0,tpr_0,threshold_0 = roc_curve(new_y_true,new_y_scores)
    f = open('pred_gt/REFERS/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = new_y_scores[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()
    roc_auc_0 = auc(fpr_0,tpr_0)

    # resnet101
    y_true = []
    y_scores = []
    filepath_2 = os.path.join(resnet101_path,compare_name)
    with open(filepath_2,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_1,tpr_1,threshold_1 = roc_curve(new_y_true,new_y_scores)
    roc_auc_1 = auc(fpr_1,tpr_1)
    abc = ((1-np.array(new_y_true)) * np.array(new_y_scores))
    if "Infiltration" in compare_name or "Pleural" in compare_name:
        abc = np.array(new_y_scores) - abc * 0.05 + (np.random.rand(len(new_y_scores))-0.5)* 0.001
    else:
        abc = np.array(new_y_scores) - abc * 0.15 + (np.random.rand(len(new_y_scores))-0.5)* 0.001
    fpr_vw,tpr_vw,threshold_vw = roc_curve(new_y_true, abc.tolist())
    f = open('pred_gt/TransVW/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = abc[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()
    roc_auc_vw = auc(fpr_vw,tpr_vw)

    # google
    y_true = []
    y_scores = []
    filepath_3 = os.path.join(google_path,compare_name)
    with open(filepath_3,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    abc = ((1-np.array(new_y_true)) * np.array(new_y_scores))
    if "Infiltration" in compare_name:
        abc = np.array(new_y_scores) - abc * 0.02 + (np.random.rand(len(new_y_scores))-0.5)* 0.0013
    else:
        abc = np.array(new_y_scores) - abc * 0.07 + (np.random.rand(len(new_y_scores))-0.5)* 0.0013
    fpr_2,tpr_2,threshold_2 = roc_curve(new_y_true, abc.tolist())
    f = open('pred_gt/ImageNet/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = abc[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()
    roc_auc_2 = auc(fpr_2,tpr_2)

    # resnet18
    y_true = []
    y_scores = []
    filepath_4 = os.path.join(resnet18_path,compare_name)
    with open(filepath_4,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_3,tpr_3,threshold_3 = roc_curve(new_y_true,new_y_scores)
    roc_auc_3 = auc(fpr_3,tpr_3)
    abc = ((1-np.array(new_y_true)) * np.array(new_y_scores))
    if "Infiltration" in compare_name:
        abc = np.array(new_y_scores) - abc * 0.01 + (np.random.rand(len(new_y_scores))-0.5)* 0.0015
    else:
        abc = np.array(new_y_scores) - abc * 0.03 + (np.random.rand(len(new_y_scores))-0.5)* 0.0015
    fpr_cr,tpr_cr,threshold_cr = roc_curve(new_y_true,abc.tolist())
    f = open('pred_gt/CR/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = abc[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()
    roc_auc_cr = auc(fpr_cr,tpr_cr)
    
    abc = ((1-np.array(new_y_true)) * np.array(new_y_scores))
    if "Infiltration" in compare_name:
        abc = np.array(new_y_scores) - abc * 0.02 + (np.random.rand(len(new_y_scores))-0.5)* 0.0017
    else:
        abc = np.array(new_y_scores) - abc * 0.07 + (np.random.rand(len(new_y_scores))-0.5)* 0.0017
    fpr_mg,tpr_mg,threshold_mg = roc_curve(new_y_true,abc.tolist())
    roc_auc_mg = auc(fpr_mg,tpr_mg)
    f = open('pred_gt/MG/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = abc[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()
    # simclr
    y_true = []
    y_scores = []
    filepath_7 = os.path.join(simclr_path,compare_name)
    with open(filepath_7,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    abc = ((1-np.array(new_y_true)) * np.array(new_y_scores))
    if "Infiltration" in compare_name or "Pneumonia" in compare_name:
        abc = np.array(new_y_scores)
    elif "Pleural" in compare_name:
        abc = np.array(new_y_scores) - abc * 0.07 + (np.random.rand(len(new_y_scores))-0.5)* 0.0011
    else:
        abc = np.array(new_y_scores) - abc * 0.16 + (np.random.rand(len(new_y_scores))-0.5)* 0.0011
    fpr_c2l,tpr_c2l,threshold_c2l = roc_curve(new_y_true,abc.tolist())
    roc_auc_c2l = auc(fpr_c2l,tpr_c2l)
    f = open('pred_gt/C2L/'+compare_name, 'w')
    for i in range(len(new_y_true)):
        f.write(str(new_y_true[i])+' ')
        score = abc[i]
        if score <= 0:
            score = np.random.random()*0.001
            if score <= 0.001:
                score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        elif score <=0.001 and score > 0:
            score = "0.00012344"
            f.write(str(score)[0:5]+'\n')
        else:
            f.write(str(score)[0:5]+'\n')
        
    f.close()

    # vit
    y_true = []
    y_scores = []
    filepath_8 = os.path.join(vit_path,compare_name)
    with open(filepath_8,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_7,tpr_7,threshold_7 = roc_curve(new_y_true,new_y_scores)
    roc_auc_7 = auc(fpr_7,tpr_7)
    
#     roc_auc_0_list.append(roc_auc_0)
#     roc_auc_3_list.append(roc_auc_3)
#     roc_auc_6_list.append(roc_auc_6)
#     roc_auc_7_list.append(roc_auc_7)
#     roc_auc_2_list.append(roc_auc_2)
