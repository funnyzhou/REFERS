# %%
import pandas as pd
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt
import os

# %%
caption_path = "./caption_50_bestauc_checkpoint"
Densenet121_path = "./Densenet121_50_bestauc_checkpoint"
google_path = "./google_50_bestauc_checkpoint"
resnet18_path = "./resnet18_50_bestauc_checkpoint"
resnet50_path = "./resnet50_50_bestauc_checkpoint"
resnet101_path = "./resnet101_50_bestauc_checkpoint"
simclr_path = "./simclr_50_bestauc_checkpoint"
vit_path = "./vit_50_bestauc_checkpoint"

# %%
one_name = "Atelectasis.txt"
two_name = "Cardiomegaly.txt"
three_name = "Consolidation.txt"
four_name = "Edema.txt"
five_name = "Effusion.txt"
six_name = "Emphysema.txt"
seven_name = "Fibrosis.txt"
eight_name = "Hernia.txt"
nine_name = "Infiltration.txt"
ten_name = "Mass.txt"
eleven_name = "Nodule.txt"
twelve_name = "Pleural_Thickening.txt"
thirteen_name = "Pneumonia.txt"
fourteen_name = "Pneumothorax.txt"

# %% [markdown]
# ## caption1

# %%
y_true = []
y_scores = []
filepath_1 = os.path.join(caption_path,one_name)
with open(filepath_1,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_0,tpr_0,threshold_0 = roc_curve(new_y_true,new_y_scores)
roc_auc_0 = auc(fpr_0,tpr_0)

# %% [markdown]
# ## densenet121

# %%
y_true = []
y_scores = []
filepath_2 = os.path.join(Densenet121_path,one_name)
with open(filepath_2,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_1,tpr_1,threshold_1 = roc_curve(new_y_true,new_y_scores)
roc_auc_1 = auc(fpr_1,tpr_1)

# %% [markdown]
# ## google

# %%
y_true = []
y_scores = []
filepath_3 = os.path.join(google_path,one_name)
with open(filepath_3,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_2,tpr_2,threshold_2 = roc_curve(new_y_true,new_y_scores)
roc_auc_2 = auc(fpr_2,tpr_2)

# %% [markdown]
# ## resnet18

# %%
y_true = []
y_scores = []
filepath_4 = os.path.join(resnet18_path,one_name)
with open(filepath_4,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_3,tpr_3,threshold_3 = roc_curve(new_y_true,new_y_scores)
roc_auc_3 = auc(fpr_3,tpr_3)

# %% [markdown]
# ## resnet50

# %%
y_true = []
y_scores = []
filepath_5 = os.path.join(resnet50_path,one_name)
with open(filepath_5,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_4,tpr_4,threshold_4 = roc_curve(new_y_true,new_y_scores)
roc_auc_4 = auc(fpr_4,tpr_4)

# %% [markdown]
# ## resnet101

# %%
y_true = []
y_scores = []
filepath_6 = os.path.join(resnet101_path,one_name)
with open(filepath_6,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_5,tpr_5,threshold_5 = roc_curve(new_y_true,new_y_scores)
roc_auc_5 = auc(fpr_5,tpr_5)

# %% [markdown]
# ## simclr

# %%
y_true = []
y_scores = []
filepath_7 = os.path.join(simclr_path,one_name)
with open(filepath_7,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_6,tpr_6,threshold_6 = roc_curve(new_y_true,new_y_scores)
roc_auc_6 = auc(fpr_6,tpr_6)

# %% [markdown]
# ## vit

# %%
y_true = []
y_scores = []
filepath_8 = os.path.join(vit_path,one_name)
with open(filepath_8,'r',encoding='utf-8') as fr:
    line_list = fr.readlines()
    for i in range(len(line_list)):
        y_true.append(line_list[i].split('\t')[0])
        y_scores.append(line_list[i].split('\t')[1].strip('\n'))

new_y_true = []
for i in range(len(y_true)):
    if y_true[i] == '1.0':
        new_y_true.append(1.0)
    else:
        new_y_true.append(0.0)
        
new_y_scores = []
for i in range(len(y_scores)):
    new_y_scores.append(float(y_scores[i]))
    
fpr_7,tpr_7,threshold_7 = roc_curve(new_y_true,new_y_scores)
roc_auc_7 = auc(fpr_7,tpr_7)

# %%
# color='darkorange'
# color='red'
plt.figure()
lw= 2 
plt.figure(figsize = (10,10))
plt.plot(fpr_0,tpr_0,lw=lw,color='red',label='Ours')
plt.plot(fpr_1,tpr_1,lw=lw,color='darkgoldenrod',label='DenseNet121')
plt.plot(fpr_2,tpr_2,lw=lw,color='gold',label='GoogleNet')
plt.plot(fpr_3,tpr_3,lw=lw,color='sandybrown',label='Resnet18')
plt.plot(fpr_4,tpr_4,lw=lw,color='saddlebrown',label='Resnet50')
plt.plot(fpr_5,tpr_5,lw=lw,color='chocolate',label='Resnet101')
plt.plot(fpr_5,tpr_5,lw=lw,color='green',label='Simclr')
plt.plot(fpr_5,tpr_5,lw=lw,color='skyblue',label='ViT')


plt.plot([0,1],[0,1],color='navy',lw=lw,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate',fontsize=18)
plt.ylabel('True Positive Rate',fontsize=18)
plt.title('Aortic enlargement',fontsize=18)
plt.legend(loc='lower right',fontsize=18)
plt.savefig('Aortic enlargement.jpg',fontsize=18)
plt.show()

# %%
one_name = "Aortic enlargement.txt"
two_name = "Atelectasis.txt"
three_name = "Calcification.txt"
four_name = "Cardiomegaly.txt"
five_name = "Consolidation.txt"
six_name = "ILD.txt"
seven_name = "Infiltration.txt"
eight_name = "Lung Opacity.txt"
nine_name = "Nodule-Mass.txt"
ten_name = "Other lesion.txt"
eleven_name = "Pleural effusion.txt"
twelve_name = "Pleural thickening.txt"
thirteen_name = "Pneumothorax.txt"
fourteen_name = "Pulmonary fibrosis.txt"

# %%
file_name_list = [one_name,two_name,three_name,four_name,five_name,six_name,seven_name,eight_name,nine_name,ten_name,eleven_name,twelve_name,thirteen_name,fourteen_name]

# %%
# caption
y_true = []
y_scores = []
for compare_name in file_name_list:
    filepath_1 = os.path.join(caption_path,compare_name)
    with open(filepath_1,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_0,tpr_0,threshold_0 = roc_curve(new_y_true,new_y_scores)
    roc_auc_0 = auc(fpr_0,tpr_0)

    # densenet121
    y_true = []
    y_scores = []
    filepath_2 = os.path.join(Densenet121_path,compare_name)
    with open(filepath_2,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_1,tpr_1,threshold_1 = roc_curve(new_y_true,new_y_scores)
    roc_auc_1 = auc(fpr_1,tpr_1)

    # google
    y_true = []
    y_scores = []
    filepath_3 = os.path.join(google_path,compare_name)
    with open(filepath_3,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_2,tpr_2,threshold_2 = roc_curve(new_y_true,new_y_scores)
    roc_auc_2 = auc(fpr_2,tpr_2)

    # resnet18
    y_true = []
    y_scores = []
    filepath_4 = os.path.join(resnet18_path,compare_name)
    with open(filepath_4,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_3,tpr_3,threshold_3 = roc_curve(new_y_true,new_y_scores)
    roc_auc_3 = auc(fpr_3,tpr_3)

    # resnet50
    y_true = []
    y_scores = []
    filepath_5 = os.path.join(resnet50_path,compare_name)
    with open(filepath_5,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_4,tpr_4,threshold_4 = roc_curve(new_y_true,new_y_scores)
    roc_auc_4 = auc(fpr_4,tpr_4)

    # resnet101
    y_true = []
    y_scores = []
    filepath_6 = os.path.join(resnet101_path,compare_name)
    with open(filepath_6,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_5,tpr_5,threshold_5 = roc_curve(new_y_true,new_y_scores)
    roc_auc_5 = auc(fpr_5,tpr_5)

    # simclr
    y_true = []
    y_scores = []
    filepath_7 = os.path.join(simclr_path,compare_name)
    with open(filepath_7,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_6,tpr_6,threshold_6 = roc_curve(new_y_true,new_y_scores)
    roc_auc_6 = auc(fpr_6,tpr_6)

    # vit
    y_true = []
    y_scores = []
    filepath_8 = os.path.join(vit_path,compare_name)
    with open(filepath_8,'r',encoding='utf-8') as fr:
        line_list = fr.readlines()
        for i in range(len(line_list)):
            y_true.append(line_list[i].split('\t')[0])
            y_scores.append(line_list[i].split('\t')[1].strip('\n'))

    new_y_true = []
    for i in range(len(y_true)):
        if y_true[i] == '1.0':
            new_y_true.append(1.0)
        else:
            new_y_true.append(0.0)

    new_y_scores = []
    for i in range(len(y_scores)):
        new_y_scores.append(float(y_scores[i]))

    fpr_7,tpr_7,threshold_7 = roc_curve(new_y_true,new_y_scores)
    roc_auc_7 = auc(fpr_7,tpr_7)

    # color='darkorange'
    # color='red'
    plt.figure()
    lw= 2 
    plt.figure(figsize = (10,10))
    plt.plot(fpr_0,tpr_0,lw=lw,color='red',label='Ours(area=%0.2f)' % roc_auc_0)
    plt.plot(fpr_1,tpr_1,lw=lw,color='darkgoldenrod',label='DenseNet121(area=%0.2f)'% roc_auc_1)
    plt.plot(fpr_2,tpr_2,lw=lw,color='gold',label='GoogleNet(area=%0.2f)'% roc_auc_2)
    plt.plot(fpr_3,tpr_3,lw=lw,color='sandybrown',label='Resnet18(area=%0.2f)'% roc_auc_3)
    plt.plot(fpr_4,tpr_4,lw=lw,color='saddlebrown',label='Resnet50(area=%0.2f)'% roc_auc_4)
    plt.plot(fpr_5,tpr_5,lw=lw,color='chocolate',label='Resnet101(area=%0.2f)'% roc_auc_5)
    plt.plot(fpr_5,tpr_5,lw=lw,color='green',label='Simclr(area=%0.2f)'% roc_auc_6)
    plt.plot(fpr_5,tpr_5,lw=lw,color='skyblue',label='ViT(area=%0.2f)'% roc_auc_7)


    plt.plot([0,1],[0,1],color='navy',lw=lw,linestyle='--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.05])
    plt.xlabel('False Positive Rate',fontsize=18)
    plt.ylabel('True Positive Rate',fontsize=18)
    plt.title(compare_name.split(".")[0],fontsize=18)
    plt.legend(loc='lower right',fontsize=18)
    plt.savefig(compare_name.split(".")[0]+'.jpg',fontsize=18)
    plt.show()
